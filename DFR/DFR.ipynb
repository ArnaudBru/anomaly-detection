# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pwd
# Out:
# '/content/drive/My Drive/Telecom_projects/Deep_Feature_Reconstruction'

# %% [markdown]
# Download whole dataset

# %%
# !wget ftp://guest:GU.205dldo@ftp.softronics.ch/mvtec_anomaly_detection/mvtec_anomaly_detection.tar.xz
# Out:
# --2021-03-16 21:59:50--  ftp://guest:*password*@ftp.softronics.ch/mvtec_anomaly_detection/mvtec_anomaly_detection.tar.xz
#            => ‘mvtec_anomaly_detection.tar.xz’
# Resolving ftp.softronics.ch (ftp.softronics.ch)... 116.203.77.152
# Connecting to ftp.softronics.ch (ftp.softronics.ch)|116.203.77.152|:21... connected.
# Logging in as guest ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /mvtec_anomaly_detection ... done.
# ==> SIZE mvtec_anomaly_detection.tar.xz ... 5264982680
# ==> PASV ... done.    ==> RETR mvtec_anomaly_detection.tar.xz ... done.
# Length: 5264982680 (4.9G) (unauthoritative)
#
# mvtec_anomaly_detec 100%[===================>]   4.90G  25.0MB/s    in 3m 21s
#
# 2021-03-16 22:03:12 (25.0 MB/s) - ‘mvtec_anomaly_detection.tar.xz’ saved [5264982680]

# %%
# !tar -xf mvtec_anomaly_detection.tar.xz

# %%
# !rm mvtec_anomaly_detection.tar.xz

# %% [markdown]
# Download bottle

# %%
# !wget ftp://guest:GU.205dldo@ftp.softronics.ch/mvtec_anomaly_detection/bottle.tar.xz
# Out:
# --2021-03-20 12:12:23--  ftp://guest:*password*@ftp.softronics.ch/mvtec_anomaly_detection/bottle.tar.xz
#            => ‘bottle.tar.xz’
# Resolving ftp.softronics.ch (ftp.softronics.ch)... 116.203.77.152
# Connecting to ftp.softronics.ch (ftp.softronics.ch)|116.203.77.152|:21... connected.
# Logging in as guest ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /mvtec_anomaly_detection ... done.
# ==> SIZE bottle.tar.xz ... 155880244
# ==> PASV ... done.    ==> RETR bottle.tar.xz ... done.
# Length: 155880244 (149M) (unauthoritative)
#
# bottle.tar.xz       100%[===================>] 148.66M  24.5MB/s    in 6.7s
#
# 2021-03-20 12:12:31 (22.1 MB/s) - ‘bottle.tar.xz’ saved [155880244]

# %%
# !tar -xf bottle.tar.xz

# %%
# !rm bottle.tar.xz

# %%
#Put your drive path here
# %cd "/content/drive/MyDrive/Telecom_projects/Deep_Feature_Reconstruction"
# Out:
# /content/drive/MyDrive/Telecom_projects/Deep_Feature_Reconstruction

# %%
# !python3 main.py

# %%
# !python3 main.py --mode evaluation
# Out:
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# loading image files /content/bottle/train/good
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# loading image files /content/bottle/test
# loading image files /content/bottle/test/good
# loading image files /content/bottle/test/broken_large
# loading image files /content/bottle/test/broken_small
# loading image files /content/bottle/test/contamination
# BN?: True
# model name: AnoSegDFR(BN)_vgg19_l12_d131_s4_k4_bilinear
# Loading model...
# model path: /content/drive/My Drive/Telecom_projects/Deep_Feature_Reconstruction/models/bottle/AnoSegDFR(BN)_vgg19_l12_d131_s4_k4_bilinear/model/autoencoder.pth
# Model Loaded.
# Calculating ROC & PR AUC metrics on testing data...
# Det AUC: 0.9960, Seg AUC: 0.9493
# Det PR: 0.9988, Seg PR: 0.5535
# Calculating IOU & PRO metrics on testing data...
# Traceback (most recent call last):
#   File "main.py", line 96, in <module>
#   File "/content/drive/My Drive/Telecom_projects/Deep_Feature_Reconstruction/anoseg_dfr.py", line 675, in metrics_evaluation
#     label_map = measure.label(masks[i], connectivity=2)
#   File "/usr/local/lib/python3.7/dist-packages/skimage/measure/_label.py", line 93, in label
#     return clabel(input, neighbors, background, return_num, connectivity)
# KeyboardInterrupt
