# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pwd
# Out:
# '/content/drive/My Drive/Telecom_projects/Deep_Feature_Reconstruction'

# %% [markdown]
# Download whole dataset

# %%
# !wget ftp://guest:GU.205dldo@ftp.softronics.ch/mvtec_anomaly_detection/mvtec_anomaly_detection.tar.xz
# !tar -xf mvtec_anomaly_detection.tar.xz
# !rm mvtec_anomaly_detection.tar.xz
# Out:
# --2021-04-01 15:53:41--  ftp://guest:*password*@ftp.softronics.ch/mvtec_anomaly_detection/mvtec_anomaly_detection.tar.xz
#            => ‘mvtec_anomaly_detection.tar.xz’
# Resolving ftp.softronics.ch (ftp.softronics.ch)... 116.203.77.152
# Connecting to ftp.softronics.ch (ftp.softronics.ch)|116.203.77.152|:21... connected.
# Logging in as guest ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /mvtec_anomaly_detection ... done.
# ==> SIZE mvtec_anomaly_detection.tar.xz ... 5264982680
# ==> PASV ... done.    ==> RETR mvtec_anomaly_detection.tar.xz ... done.
# Length: 5264982680 (4.9G) (unauthoritative)
#
#       mvtec_anomaly   0%[                    ]   3.17M  2.81MB/s               ^C

# %% [markdown]
# Download bottle

# %%
# !wget ftp://guest:GU.205dldo@ftp.softronics.ch/mvtec_anomaly_detection/bottle.tar.xz
# !tar -xf bottle.tar.xz
# !rm bottle.tar.xz
# Out:
# --2021-04-01 17:13:45--  ftp://guest:*password*@ftp.softronics.ch/mvtec_anomaly_detection/bottle.tar.xz
#            => ‘bottle.tar.xz’
# Resolving ftp.softronics.ch (ftp.softronics.ch)... 116.203.77.152
# Connecting to ftp.softronics.ch (ftp.softronics.ch)|116.203.77.152|:21... connected.
# Logging in as guest ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /mvtec_anomaly_detection ... done.
# ==> SIZE bottle.tar.xz ... 155880244
# ==> PASV ... done.    ==> RETR bottle.tar.xz ... done.
# Length: 155880244 (149M) (unauthoritative)
#
# bottle.tar.xz       100%[===================>] 148.66M  18.3MB/s    in 9.0s
#
# 2021-04-01 17:13:56 (16.4 MB/s) - ‘bottle.tar.xz’ saved [155880244]

# %% [markdown]
# Download metal nut

# %%
# !wget ftp://guest:GU.205dldo@ftp.softronics.ch/mvtec_anomaly_detection/metal_nut.tar.xz
# !tar -xf metal_nut.tar.xz
# !rm metal_nut.tar.xz
# Out:
# --2021-04-01 17:14:07--  ftp://guest:*password*@ftp.softronics.ch/mvtec_anomaly_detection/metal_nut.tar.xz
#            => ‘metal_nut.tar.xz’
# Resolving ftp.softronics.ch (ftp.softronics.ch)... 116.203.77.152
# Connecting to ftp.softronics.ch (ftp.softronics.ch)|116.203.77.152|:21... connected.
# Logging in as guest ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /mvtec_anomaly_detection ... done.
# ==> SIZE metal_nut.tar.xz ... 165414484
# ==> PASV ... done.    ==> RETR metal_nut.tar.xz ... done.
# Length: 165414484 (158M) (unauthoritative)
#
# metal_nut.tar.xz    100%[===================>] 157.75M  18.3MB/s    in 9.6s
#
# 2021-04-01 17:14:19 (16.4 MB/s) - ‘metal_nut.tar.xz’ saved [165414484]

# %%
#Put your drive path here
# %cd "/content/drive/MyDrive/Telecom_projects/Deep_Feature_Reconstruction"
# Out:
# /content/drive/MyDrive/Telecom_projects/Deep_Feature_Reconstruction

# %%
# !python3 main.py --data_name metal_nut
# Out:
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# loading image files /content/metal_nut/train/good
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# loading image files /content/metal_nut/test
# loading image files /content/metal_nut/test/color
# loading image files /content/metal_nut/test/good
# loading image files /content/metal_nut/test/flip
# loading image files /content/metal_nut/test/scratch
# loading image files /content/metal_nut/test/bent
# data name: metal_nut
# Estimating one class classifier AE parameter...
# AE Parameter (in_feat, n_dim): (3456, 377)
# model name: AnoSegDFR(BN)_vgg19_metal_nut_l12_d377_s4_k4_bilinear
# Loading model...
# model path: /content/drive/My Drive/Telecom_projects/Deep_Feature_Reconstruction/models/metal_nut/AnoSegDFR(BN)_vgg19_metal_nut_l12_d377_s4_k4_bilinear/model/autoencoder.pth
# No existing models found.
# Epoch 5/50
# ----------
# Elapsed 0:03:43.228319/0:00:00.676449 -- 0:27:17.684120 , Epoch [5/50], Iter [55/55], total_loss: 0.8827
# Epoch 10/50
# ----------
# Elapsed 0:07:33.714605/0:00:00.749941 -- 0:26:49.374450 , Epoch [10/50], Iter [55/55], total_loss: 0.6058
# auc: 0.8697631367440442
# Epoch 15/50
# ----------
# Elapsed 0:11:40.467218/0:00:00.795985 -- 0:24:49.288824 , Epoch [15/50], Iter [55/55], total_loss: 0.5338
# Epoch 20/50
# ----------
# Elapsed 0:15:31.019921/0:00:00.806078 -- 0:21:26.500254 , Epoch [20/50], Iter [55/55], total_loss: 0.4417
# auc: 0.8986905194728076
# Epoch 25/50
# ----------
# Elapsed 0:19:37.978423/0:00:00.823761 -- 0:18:08.188459 , Epoch [25/50], Iter [55/55], total_loss: 0.4370
# Epoch 30/50
# ----------
# Elapsed 0:23:29.447678/0:00:00.826656 -- 0:14:24.681684 , Epoch [30/50], Iter [55/55], total_loss: 0.4233
# auc: 0.909046661693089
# Epoch 35/50
# ----------
# Elapsed 0:27:36.246270/0:00:00.836488 -- 0:10:44.932260 , Epoch [35/50], Iter [55/55], total_loss: 0.3904
# Epoch 40/50
# ----------
# Elapsed 0:31:27.191017/0:00:00.836892 -- 0:06:55.098334 , Epoch [40/50], Iter [55/55], total_loss: 0.3639
# auc: 0.9139703657738728
# Epoch 45/50
# ----------
# Elapsed 0:35:34.060744/0:00:00.843502 -- 0:03:06.414002 , Epoch [45/50], Iter [55/55], total_loss: 0.3399
# Epoch 50/50
# ----------
# Elapsed 0:39:25.439304/0:00:00.843294 -- -1 day, 23:59:14.462131 , Epoch [50/50], Iter [55/55], total_loss: 0.3467
# auc: 0.9169173496244959
# Cost total time 2381.2547509670258s
# Done.

# %%
# !python3 main.py --data_name metal_nut --mode evaluation
# Out:
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# ##################Reflection Padding#######################
# loading image files /content/metal_nut/train/good
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# loading image files /content/metal_nut/test
# loading image files /content/metal_nut/test/color
# loading image files /content/metal_nut/test/good
# loading image files /content/metal_nut/test/flip
# loading image files /content/metal_nut/test/scratch
# loading image files /content/metal_nut/test/bent
# metal_nut 12 377
# model name: AnoSegDFR(BN)_vgg19_metal_nut_l12_d377_s4_k4_bilinear
# Loading model...
# model path: /content/drive/My Drive/Telecom_projects/Deep_Feature_Reconstruction/models/metal_nut/AnoSegDFR(BN)_vgg19_metal_nut_l12_d377_s4_k4_bilinear/model/autoencoder.pth
# Model Loaded.
# Calculating ROC & PR AUC metrics on testing data...
# Det AUC: 0.9096, Seg AUC: 0.9169
# Det PR: 0.9791, Seg PR: 0.6118
# Calculating IOU & PRO metrics on testing data...
# Best IOU: 0.3414
# pro auc (30% FPR): 0.8431654300296986
